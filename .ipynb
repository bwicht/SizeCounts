# %%
import time
import matplotlib.dates as mdates
import _pickle as pickle
from tqdm import tqdm
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import pathlib as path

# %%
data = pd.read_csv('./Data/geonames-all-cities-with-a-population-1000.csv',delimiter =';')
data = data[["Name","Population","Country","Coordinates"]] 
data.to_csv("data.csv")
data.to_json("data.json")
